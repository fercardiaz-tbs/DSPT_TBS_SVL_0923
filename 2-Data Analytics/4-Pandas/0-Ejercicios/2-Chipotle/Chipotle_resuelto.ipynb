# %% [markdown]
# # Ex1 - Filtrar y ordenar datos

# %% [markdown]
# ### Paso 1. Importar las bibliotecas necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Paso 2. Importa el conjunto de datos de esta [dirección](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) y asígnalos a una variable llamada chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Paso 3. Nombre del producto de valor máximo

# %%
chipo.item_price = chipo.item_price.str.replace("$","").astype(float)
# Out:
# C:\Users\Fernando Carrasco\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo[chipo.order_id == 1443]
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3599      1443         7                 Bottled Water
# 3600      1443         1             6 Pack Soft Drink
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 3603      1443         3                 Steak Burrito
# 3604      1443         2                 Bottled Water
#
#                                      choice_description  item_price  \
# 3598                                                NaN       44.25
# 3599                                                NaN       10.50
# 3600                                             [Coke]        6.49
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       27.75
# 3604                                                NaN        3.00
#
#       productprice
# 3598          2.95
# 3599          1.50
# 3600          6.49
# 3601         11.25
# 3602          8.75
# 3603          9.25
# 3604          1.50

# %%
chipo[(chipo.item_name == 'Chips and Fresh Tomato Salsa') & (chipo.productprice == 2.39)]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 265        115         1  Chips and Fresh Tomato Salsa                NaN
# 302        131         1  Chips and Fresh Tomato Salsa                NaN
# 326        142         1  Chips and Fresh Tomato Salsa                NaN
# 848        349         1  Chips and Fresh Tomato Salsa                NaN
# 962        395         1  Chips and Fresh Tomato Salsa                NaN
# 1247       508         1  Chips and Fresh Tomato Salsa                NaN
# 1465       595         1  Chips and Fresh Tomato Salsa                NaN
# 1498       608         1  Chips and Fresh Tomato Salsa                NaN
# 1788       723         1  Chips and Fresh Tomato Salsa                NaN
# 1809       732         1  Chips and Fresh Tomato Salsa                NaN
# 1905       769         1  Chips and Fresh Tomato Salsa                NaN
# 2055       828         1  Chips and Fresh Tomato Salsa                NaN
# 2064       832         1  Chips and Fresh Tomato Salsa                NaN
# 2082       840         1  Chips and Fresh Tomato Salsa                NaN
# 2117       852         1  Chips and Fresh Tomato Salsa                NaN
# 2391       950         1  Chips and Fresh Tomato Salsa                NaN
# 2431       965         1  Chips and Fresh Tomato Salsa                NaN
# 2436       967         1  Chips and Fresh Tomato Salsa                NaN
# 2445       971         1  Chips and Fresh Tomato Salsa                NaN
# 2494       990         1  Chips and Fresh Tomato Salsa                NaN
# 2512       998         1  Chips and Fresh Tomato Salsa                NaN
# 2657      1055         1  Chips and Fresh Tomato Salsa                NaN
# 2841      1128         1  Chips and Fresh Tomato Salsa                NaN
# 2910      1156         1  Chips and Fresh Tomato Salsa                NaN
# 3155      1259         1  Chips and Fresh Tomato Salsa                NaN
# 3226      1290         1  Chips and Fresh Tomato Salsa                NaN
# 3228      1291         1  Chips and Fresh Tomato Salsa                NaN
# 3475      1396         1  Chips and Fresh Tomato Salsa                NaN
# 3506      1408         1  Chips and Fresh Tomato Salsa                NaN
# 3608      1445         1  Chips and Fresh Tomato Salsa                NaN
# 3907      1566         1  Chips and Fresh Tomato Salsa                NaN
# 3983      1596         1  Chips and Fresh Tomato Salsa                NaN
# 4090      1638         1  Chips and Fresh Tomato Salsa                NaN
#
#       item_price  productprice
# 0           2.39          2.39
# 25          2.39          2.39
# 55          2.39          2.39
# 265         2.39          2.39
# 302         2.39          2.39
# 326         2.39          2.39
# 848         2.39          2.39
# 962         2.39          2.39
# 1247        2.39          2.39
# 1465        2.39          2.39
# 1498        2.39          2.39
# 1788        2.39          2.39
# 1809        2.39          2.39
# 1905        2.39          2.39
# 2055        2.39          2.39
# 2064        2.39          2.39
# 2082        2.39          2.39
# 2117        2.39          2.39
# 2391        2.39          2.39
# 2431        2.39          2.39
# 2436        2.39          2.39
# 2445        2.39          2.39
# 2494        2.39          2.39
# 2512        2.39          2.39
# 2657        2.39          2.39
# 2841        2.39          2.39
# 2910        2.39          2.39
# 3155        2.39          2.39
# 3226        2.39          2.39
# 3228        2.39          2.39
# 3475        2.39          2.39
# 3506        2.39          2.39
# 3608        2.39          2.39
# 3907        2.39          2.39
# 3983        2.39          2.39
# 4090        2.39          2.39

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
#       productprice
# 0             2.39
# 1             3.39
# 2             3.39
# 3             2.39
# 4             8.49
# ...            ...
# 4617         11.75
# 4618         11.75
# 4619         11.25
# 4620          8.75
# 4621          8.75
#
# [4622 rows x 6 columns]

# %%
chipo[chipo.item_price == chipo.item_price.max()]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Paso 4. ¿Cuántos productos cuestan más de 10 dólares?

# %%
chipo[chipo.item_price > 10].shape[0]
# Out:
# 1130

# %%
chipo['productprice'] = chipo.item_price/chipo.quantity

# %%
masc1 = chipo.item_name == 'Chips and Fresh Tomato Salsa'

# %%
chipo[masc1].value_counts(chipo.productprice)
# Out:
# productprice
# 2.95    71
# 2.39    36
# 2.29     3
# dtype: int64

# %%
chipo3 = chipo.drop(columns=['order_id','quantity','choice_description','item_price'],axis=1)

# %%
chipo3
# Out:
#                                   item_name  productprice
# 0              Chips and Fresh Tomato Salsa          2.39
# 1                                      Izze          3.39
# 2                          Nantucket Nectar          3.39
# 3     Chips and Tomatillo-Green Chili Salsa          2.39
# 4                              Chicken Bowl          8.49
# ...                                     ...           ...
# 4617                          Steak Burrito         11.75
# 4618                          Steak Burrito         11.75
# 4619                     Chicken Salad Bowl         11.25
# 4620                     Chicken Salad Bowl          8.75
# 4621                     Chicken Salad Bowl          8.75
#
# [4622 rows x 2 columns]

# %%
chipo3 = chipo3.groupby(['item_name','productprice'])['productprice'].count()

# %%
chipo3
# Out:
# item_name          productprice
# 6 Pack Soft Drink  6.49            54
# Barbacoa Bowl      8.69             3
#                    8.99             8
#                    9.25            28
#                    11.48            6
#                                    ..
# Veggie Salad Bowl  8.75             8
#                    11.25           10
# Veggie Soft Tacos  8.49             3
#                    8.75             2
#                    11.25            2
# Name: productprice, Length: 139, dtype: int64

# %%
chipo3 = pd.DataFrame(chipo3)

# %%
chipo3.rename(columns={"productprice": "conteo"})
# Out:
#                                 conteo
# item_name         productprice
# 6 Pack Soft Drink 6.49              54
# Barbacoa Bowl     8.69               3
#                   8.99               8
#                   9.25              28
#                   11.48              6
# ...                                ...
# Veggie Salad Bowl 8.75               8
#                   11.25             10
# Veggie Soft Tacos 8.49               3
#                   8.75               2
#                   11.25              2
#
# [139 rows x 1 columns]

# %%
chipo3.set_index(keys=['productprice'], inplace=True)

# %%
chipo3
# Out:
# Empty DataFrame
# Columns: []
# Index: [54, 3, 8, 28, 6, 1, 20, 2, 19, 46, 1, 1, 22, 2, 5, 1, 3, 5, 5, 2, 15, 1, 7, 27, 135, 1, 1, 6, 104, 301, 14, 22, 3, 7, 22, 2, 9, 29, 1, 2, 16, 3, 2, 2, 1, 2, 4, 6, 31, 3, 3, 114, 2, 325, 1, 1, 49, 231, 11, 106, 256, 4, 45, 131, 9, 23, 1, 14, 1, 6, 2, 59, 51, 29, 60, 4, 22, 1, 210, 3, 36, 71, 6, 99, 2, 1, 371, 1, 22, 18, 43, 48, 31, 20, 2, 20, 27, 2, 100, 1, ...]
#
# [139 rows x 0 columns]

# %% [markdown]
# Extra: Cuántos pedidos se han hecho con un producto de más de 10$

# %%
chipo[chipo.item_price > 10].groupby('order_id').count()
# Out:
#           quantity  item_name  choice_description  item_price
# order_id
# 2                1          1                   1           1
# 3                1          1                   1           1
# 4                1          1                   1           1
# 7                1          1                   1           1
# 12               1          1                   1           1
# ...            ...        ...                 ...         ...
# 1825             5          5                   5           5
# 1829             2          2                   2           2
# 1830             2          2                   2           2
# 1833             2          2                   2           2
# 1834             1          1                   1           1
#
# [863 rows x 4 columns]

# %%
chipo[chipo.item_price > 10].nunique()
# Out:
# order_id              863
# quantity                8
# item_name              31
# choice_description    492
# item_price             35
# dtype: int64

# %%
# chipo[chipo.item_price > 10].groupby('order_id').count()

chipo[chipo.item_price > 10].nunique()
chipo[chipo.item_price > 10]['order_id'].nunique()

chipo[chipo.item_price > 10]['order_id'].value_counts()
# Out:
# 691     8
# 1786    7
# 1559    5
# 491     5
# 577     5
#        ..
# 704     1
# 705     1
# 707     1
# 712     1
# 1834    1
# Name: order_id, Length: 863, dtype: int64

# %% [markdown]
# ### Paso 5. ¿Cuál es el precio de cada artículo? Obtenga sólo item_name y unit_price

# %%
chipo['unit_price'] = chipo.item_price / chipo.quantity
chipo['item_name'] = chipo['item_name'].str.replace("-"," ")

chipo[['item_name','unit_price']].groupby('item_name').max()
# Out:
#                                        unit_price
# item_name
# 6 Pack Soft Drink                            6.49
# Barbacoa Bowl                               11.75
# Barbacoa Burrito                            11.75
# Barbacoa Crispy Tacos                       11.75
# Barbacoa Salad Bowl                         11.89
# Barbacoa Soft Tacos                         11.75
# Bottled Water                                1.50
# Bowl                                         7.40
# Burrito                                      7.40
# Canned Soda                                  1.09
# Canned Soft Drink                            1.25
# Carnitas Bowl                               11.75
# Carnitas Burrito                            11.75
# Carnitas Crispy Tacos                       11.75
# Carnitas Salad                               8.99
# Carnitas Salad Bowl                         11.89
# Carnitas Soft Tacos                         11.75
# Chicken Bowl                                11.25
# Chicken Burrito                             11.25
# Chicken Crispy Tacos                        11.25
# Chicken Salad                               10.98
# Chicken Salad Bowl                          11.25
# Chicken Soft Tacos                          11.25
# Chips                                        2.15
# Chips and Fresh Tomato Salsa                 2.95
# Chips and Guacamole                          4.45
# Chips and Mild Fresh Tomato Salsa            3.00
# Chips and Roasted Chili Corn Salsa           2.95
# Chips and Tomatillo Green Chili Salsa        2.95
# Chips and Tomatillo Red Chili Salsa          2.95
# Crispy Tacos                                 7.40
# Izze                                         3.39
# Nantucket Nectar                             3.39
# Salad                                        7.40
# Side of Chips                                1.69
# Steak Bowl                                  11.75
# Steak Burrito                               11.75
# Steak Crispy Tacos                          11.75
# Steak Salad                                  8.99
# Steak Salad Bowl                            11.89
# Steak Soft Tacos                            11.75
# Veggie Bowl                                 11.25
# Veggie Burrito                              11.25
# Veggie Crispy Tacos                          8.49
# Veggie Salad                                 8.49
# Veggie Salad Bowl                           11.25
# Veggie Soft Tacos                           11.25

# %% [markdown]
# ### Paso 6. Ordenar por el nombre del artículo

# %%
chipo.sort_values(by='item_name',ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...                                                 ...         ...
# 2384  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 781   [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...        8.75
# 2851  [Roasted Chili Corn Salsa (Medium), [Black Bea...        8.49
# 1699  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 1395  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...        8.49
#
#       productprice  unit_price
# 3389          6.49        6.49
# 341           6.49        6.49
# 1849          6.49        6.49
# 1860          6.49        6.49
# 2713          6.49        6.49
# ...            ...         ...
# 2384          8.75        8.75
# 781           8.75        8.75
# 2851          8.49        8.49
# 1699         11.25       11.25
# 1395          8.49        8.49
#
# [4622 rows x 7 columns]

# %% [markdown]
# ### Paso 7. ¿Cuál fue la cantidad del artículo más caro pedido? 2 formas

# %%
chipo[chipo.item_price == chipo.item_price.max()]['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
chipo.loc[chipo['item_price'].idxmax(), 'quantity']
# Out:
# 15

# %% [markdown]
# ## Paso 7.1: Cantidad de ARTICULOS del pedido MAS CARO

# %%
chipo[chipo.order_id == 926]
# Out:
#       order_id  quantity           item_name  \
# 2304       926         1       Steak Burrito
# 2305       926         1        Chicken Bowl
# 2306       926         1        Chicken Bowl
# 2307       926         1        Chicken Bowl
# 2308       926         1          Steak Bowl
# 2309       926         1        Chicken Bowl
# 2310       926         1       Steak Burrito
# 2311       926         1     Chicken Burrito
# 2312       926         1        Chicken Bowl
# 2313       926         1        Chicken Bowl
# 2314       926         1  Chicken Salad Bowl
# 2315       926         1          Steak Bowl
# 2316       926         1     Chicken Burrito
# 2317       926         1          Steak Bowl
# 2318       926         1        Chicken Bowl
# 2319       926         1          Steak Bowl
# 2320       926         1     Chicken Burrito
# 2321       926         1        Chicken Bowl
# 2322       926         1        Chicken Bowl
# 2323       926         1    Barbacoa Burrito
# 2324       926         1     Chicken Burrito
# 2325       926         1          Steak Bowl
# 2326       926         1         Veggie Bowl
#
#                                      choice_description  item_price  \
# 2304  [Fresh Tomato Salsa, [Rice, Sour Cream, Lettuce]]        9.25
# 2305  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 2306  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 2307  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 2308  [Fresh Tomato Salsa, [Rice, Black Beans, Lettu...        9.25
# 2309  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 2310  [Roasted Chili Corn Salsa, [Rice, Cheese, Sour...        9.25
# 2311  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 2312              [Fresh Tomato Salsa, [Rice, Lettuce]]        8.75
# 2313  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...        8.75
# 2314     [Roasted Chili Corn Salsa, [Rice, Sour Cream]]        8.75
# 2315  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        9.25
# 2316  [Roasted Chili Corn Salsa, [Rice, Black Beans,...        8.75
# 2317  [Roasted Chili Corn Salsa, [Rice, Black Beans,...        9.25
# 2318  [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# 2319               [Fresh Tomato Salsa, [Rice, Cheese]]        9.25
# 2320      [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]        8.75
# 2321  [Roasted Chili Corn Salsa, [Rice, Pinto Beans,...        8.75
# 2322         [Roasted Chili Corn Salsa, [Rice, Cheese]]        8.75
# 2323  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        9.25
# 2324  [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...        8.75
# 2325  [Tomatillo Red Chili Salsa, [Rice, Black Beans...        9.25
# 2326  [Roasted Chili Corn Salsa, [Rice, Black Beans,...        8.75
#
#       productprice  unit_price
# 2304          9.25        9.25
# 2305          8.75        8.75
# 2306          8.75        8.75
# 2307          8.75        8.75
# 2308          9.25        9.25
# 2309          8.75        8.75
# 2310          9.25        9.25
# 2311          8.75        8.75
# 2312          8.75        8.75
# 2313          8.75        8.75
# 2314          8.75        8.75
# 2315          9.25        9.25
# 2316          8.75        8.75
# 2317          9.25        9.25
# 2318          8.75        8.75
# 2319          9.25        9.25
# 2320          8.75        8.75
# 2321          8.75        8.75
# 2322          8.75        8.75
# 2323          9.25        9.25
# 2324          8.75        8.75
# 2325          9.25        9.25
# 2326          8.75        8.75

# %%
chipo.groupby('order_id').sum().sort_values('item_price',ascending=False)
# Out:
#           quantity  item_price  productprice  unit_price
# order_id
# 926             23      205.25        205.25      205.25
# 1443            35      160.74         41.69       41.69
# 1483            14      139.00        139.00      139.00
# 691             11      118.25        118.25      118.25
# 1786            20      114.30         93.45       93.45
# ...            ...         ...           ...         ...
# 17               2       10.08         10.08       10.08
# 889              2       10.08         10.08       10.08
# 1014             2       10.08         10.08       10.08
# 1303             2       10.08         10.08       10.08
# 1602             2       10.08         10.08       10.08
#
# [1834 rows x 4 columns]

# %%
chipo71 = chipo.groupby('order_id').sum().sort_values('item_price',ascending=False)

# %%
chipo71.loc[926,'quantity']
# Out:
# 23

# %%
chipo71.iloc[0,0]

# %%
chipo71['quantity'].iloc[0]
# Out:
# 23

# %%
chipo71
# Out:
#           quantity  item_price  productprice  unit_price
# order_id
# 926             23      205.25        205.25      205.25
# 1443            35      160.74         41.69       41.69
# 1483            14      139.00        139.00      139.00
# 691             11      118.25        118.25      118.25
# 1786            20      114.30         93.45       93.45
# ...            ...         ...           ...         ...
# 17               2       10.08         10.08       10.08
# 889              2       10.08         10.08       10.08
# 1014             2       10.08         10.08       10.08
# 1303             2       10.08         10.08       10.08
# 1602             2       10.08         10.08       10.08
#
# [1834 rows x 4 columns]

# %%
#chipo71['quantity'][0] NO SE PUEDE HACER
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Fernando Carrasco\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\Fernando Carrasco\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\Fernando Carrasco\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10284\1812909354.py in <module>
# ----> 1 chipo71['quantity'][0]
#
# c:\Users\Fernando Carrasco\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# c:\Users\Fernando Carrasco\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# c:\Users\Fernando Carrasco\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %% [markdown]
# ### Paso 8. ¿Cuántas veces se pidió una Veggie Salad Bowl?

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl']['quantity']
# Out:
# 186     1
# 295     1
# 455     1
# 496     1
# 960     1
# 1316    1
# 1884    1
# 2156    1
# 2223    1
# 2269    1
# 2683    1
# 3223    1
# 3293    1
# 4109    1
# 4201    1
# 4261    1
# 4541    1
# 4573    1
# Name: quantity, dtype: int64

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl']['quantity'].sum()
# Out:
# 18

# %%
chipo[chipo['item_name'].str.contains('Veggie Salad Bowl')]['quantity'].count()
# Out:
# 18

# %% [markdown]
# ### Paso 9. ¿Cuántas veces pidió alguien más de un Canned Soda?

# %%
chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)].shape
# Out:
# (20, 6)

# %% [markdown]
# Extra

# %%
# 1º Filtrar con una máscara: chipo[chipo["item_name"] == "Canned Soda"]
# 2º Agrupar las orders y canned sodas sumando las cantitades totales .groupby(['order_id','item_name'], as_index= False)
# 3º Quiero sumar solo la columna de quantity [['quantity']].sum()
